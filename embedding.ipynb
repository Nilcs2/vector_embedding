# %%
import numpy as np
import os

# %%
# distance formula
def cosine_similarity(v1, array_of_vectors):
    """
    compute the cosine similarity between a vector and the array of vectors.
    Parameters are as following:
    v1(array-like): The first vector.
    array_of_vectors(array-like): An array or list of vectors or a single vector.
    Returns:
    list: A list of cosine similarities between v1 and all the elements of array_of_vectors.
    """
    # making sure that the v1 is a numpy array.
    v1 = np.array(v1)
    # initilizing an empty list to store the similarities
    similarities = []

    #check for array_of_vectors if it a single element array ot not.
    if len(np.shape(array_of_vectors)) == 1:
        array_of_vectors = [array_of_vectors]

    for v2 in array_of_vectors:
        # convert the current vector into a numpy vector
        v2 = np.array(v2)
        #compute the dot product of v1 and v2
        dot_product = np.dot(v1, v2)
        #compute the norms of the vectors
        norm_v1 = np.linalg.norm(v1)
        norm_v2 = np.linalg.norm(v2)
        #compute the cosine similarity and append the empty list
        similarity = dot_product/(norm_v1 * norm_v2)
        similarities.append(similarity)
    return [float(x) for x in similarities]

def euclidean_distance(v1, array_of_vectors):
    """
    compute the euclidean distance between a vector and the array of vectors.
    Parameters are as following:
    v1(array-like): The first vector.
    array_of_vectors(array-like): An array or list of vectors or a single vector.
    Returns:
    list: A list of cosine similarities between v1 and all the elements of array_of_vectors.
    """
    #ensuring that v1 is a np array
    v1 = np.array(v1)
    #initialize an empty list to store the distances
    distances = []

    #check if array of distances is a single vector
    if len(np.shape(array_of_vectors)) == 1:
        array_of_vectors = [array_of_vectors]
    # iterate over each vector in the array
    for v2 in array_of_vectors:
        v2 = np.array(v2)
        #check if the input arrays have the same shape
        if v1.shape != v2.shape:
            raise ValueError(f"Shapes don't match: v1 shape: {v1.shape}, v2 shape: {v2.shape}")
        #calculate the euclidean distance
        dist = np.sqrt(np.sum((v1 - v2) ** 2))
        distances.append(dist)
    return [float(x) for x in distances]

# %%
v1 = [1, 2]
v2 = [1, 1]
array_v = [[3, 2], [5, 6]]
cosine_v1_v2 = cosine_similarity(v1, v2)
cosine_v1_array_v = cosine_similarity(v1, array_v)
euclidean_v1_v2 = euclidean_distance(v1, v2)
euclidean_v1_array_v = euclidean_distance(v1, array_v)

print(f"Cosine similarity between v1 and v2: {cosine_v1_v2}")
print(f"Cosine similarity between v1 and array_v: {cosine_v1_array_v}")
print(f"Euclidean distance between v1 and v2: {euclidean_v1_v2}")
print(f"Euclidean distance between v1 and array_v: {euclidean_v1_array_v}")
# Out:
# Cosine similarity between v1 and v2: [0.9486832980505138]
# Cosine similarity between v1 and array_v: [0.8682431421244593, 0.973417168333576]
# Euclidean distance between v1 and v2: [1.0]
# Euclidean distance between v1 and array_v: [2.0, 5.656854249492381]

# %%
from sentence_transformers import SentenceTransformer
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# load the pre-trained model
model_name = "BAAI/bge-base-en-v1.5"

model = SentenceTransformer(model_name, device="cpu")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# to get a string embedded, we just need to pass it to the model.
res = model.encode("RAG is awesome")
print(res.shape)
# Out:
# (768,)

# %%
# We can pass an array of strings and the ouput will be array of vectors, each will have 768 dimensions
model.encode(['apple', 'dog', 'car', 'friend'])
# Out:
# array([[-0.02102228,  0.06316212,  0.00100859, ..., -0.00027874,
#          0.00038427, -0.02818082],
#        [-0.02785037,  0.01979048, -0.04256622, ..., -0.02595475,
#          0.03766256, -0.00314069],
#        [ 0.00472381,  0.0158352 ,  0.04418223, ..., -0.057675  ,
#          0.042695  , -0.00054625],
#        [-0.02221701, -0.01183381,  0.00925158, ...,  0.03597707,
#          0.02093327,  0.04391225]], shape=(4, 768), dtype=float32)

# %%
print(res[:100])
# Out:
# [ 0.00886308 -0.04775135 -0.00156082  0.01309999 -0.00206929 -0.0615726
#   0.0138469   0.00101499 -0.0490395  -0.04762555 -0.03628183  0.00478043
#  -0.03492187  0.0532315   0.02193959  0.03645149  0.04029364 -0.00453637
#   0.01883799 -0.03367381  0.02516187 -0.04843628 -0.04047944  0.02590901
#   0.02175235  0.03160362  0.03937939 -0.03640447 -0.03113304 -0.0124723
#   0.0366165  -0.00458199 -0.00100171 -0.03188786  0.02957141  0.01986151
#  -0.00737465  0.02370173 -0.02151625 -0.07361353 -0.01723555 -0.01986936
#   0.04129727  0.00490014 -0.02677388  0.02022936  0.02961312  0.04925792
#  -0.01277175 -0.03432123 -0.01399986  0.05282126 -0.0047783  -0.01757413
#   0.02563435  0.0164731   0.0227731   0.00401536  0.01687659 -0.02709747
#  -0.05021415  0.00170134  0.00196172 -0.01983807  0.01350141  0.03220808
#  -0.02747842  0.00955016 -0.0296628  -0.03902558  0.03015527  0.01090193
#  -0.06928953  0.00174676  0.03988376 -0.00745267  0.02402291 -0.00481083
#   0.01576151  0.06735047  0.00206449 -0.02449714  0.01636326  0.092768
#   0.02036082 -0.02404021  0.00700787  0.00352969 -0.0212203   0.08323743
#  -0.00039685 -0.00399915  0.04204373  0.04737597  0.03349977 -0.01820838
#   0.00580087 -0.04418705 -0.0360661  -0.01779397]

# %%
words = ['bruce', 'wayne', 'batman', 'robin', 'alfred', 'butler', 'batwoman', 'batmobile']
vectorized_words = model.encode(words)

# %%
word = 'bruce'
print(f"{word}:")
for i, w in enumerate(words):
    # Get the vectorized word for the word defined above
    vectorized_word = vectorized_words[words.index(word)]
    print(f"\t{w}:\t\tCosine Similarity: {cosine_similarity(vectorized_word, vectorized_words[i])[0]:.4f}")
print("\n\n\n")

for i, w in enumerate(words):
    # Get the vectorized word for the word defined above
    vectorized_word = vectorized_words[words.index(word)]
    print(f"\t{w}:\t\tEuclidean Distance: {euclidean_distance(vectorized_word, vectorized_words[i])[0]:.4f}")
# Out:
# bruce:
# 	bruce:		Cosine Similarity: 1.0000
# 	wayne:		Cosine Similarity: 0.5673
# 	batman:		Cosine Similarity: 0.6608
# 	robin:		Cosine Similarity: 0.5785
# 	alfred:		Cosine Similarity: 0.6325
# 	butler:		Cosine Similarity: 0.4905
# 	batwoman:		Cosine Similarity: 0.5123
# 	batmobile:		Cosine Similarity: 0.5402
#
#
#
#
# 	bruce:		Euclidean Distance: 0.0000
# 	wayne:		Euclidean Distance: 0.9303
# 	batman:		Euclidean Distance: 0.8237
# 	robin:		Euclidean Distance: 0.9181
# 	alfred:		Euclidean Distance: 0.8573
# 	butler:		Euclidean Distance: 1.0094
# 	batwoman:		Euclidean Distance: 0.9876
# 	batmobile:		Euclidean Distance: 0.9589

# %%
def retrieve_relevant(query, documents, metric='cosine_similarity'):
    """
    Retrieves and ranks documents based on their similarity to a given query using the specified metric.
    
    Parameters:
    query (str): The query string for which relevant documents are to be retrieved.
    documents (list of str): A list of documents to be compared against the query.
    metric (str, optional): The similarity measurement metric to be used. It supports 'cosine_similarity'
                            and 'euclidean'. Defaults to 'cosine_similarity'.
    
    Returns:
    list of tuples: A list of tuples where each tuple contains a document and its similarity or distance
                    score with respect to the query. The list is sorted based on these scores, with
                    descending order for 'cosine_similarity' and ascending order for 'euclidean'.
    """
    query_emb = model.encode(query)
    documents_emb = model.encode(documents)
    vals = []

    if metric == 'cosine_similarity':
        distances = cosine_similarity(query_emb, documents_emb)
        vals = [(doc, dist) for doc, dist in zip(documents, distances)]
        # sort in descending order
        vals.sort(reverse=True, key=lambda x: x[1])

    elif metric == 'euclidean_distance':
        distances = euclidean_distance(query_emb, documents_emb)
        vals = [(doc, dist) for doc, dist in zip(documents, distances)]
        # sort in ascending order
        vals.sort(key=lambda x: x[1])

    return vals

# %%
documents = [
    "Mt. Fuji is a breathtaking place to explore during autumn.",
    "Santorini offers stunning views to admire during spring.",
    "Banff National Park is a picturesque destination to visit in the summer.",
    "The Great Wall of China is a spectacular site to experience during winter.",
    "The fjords of Norway are a magical place to cruise through in the spring.",
    "Prague is an enchanting city to wander through in winter.",
    "Kyoto's cherry blossoms create a beautiful scene to witness during spring.",
    "Marrakech offers vibrant markets and culture to enjoy in the fall.",
    "The Maldives are a paradisiacal getaway to savor during summer.",
    "The Christmas markets in Vienna are a festive delight to explore in winter."
]

query = "Suggest to me great places to visit in Asia."
score = retrieve_relevant(query, documents, metric='cosine_similarity')
score
# Out:
# [('The Great Wall of China is a spectacular site to experience during winter.',
#   0.6080518960952759),
#  ('Mt. Fuji is a breathtaking place to explore during autumn.',
#   0.5821490287780762),
#  ('The Maldives are a paradisiacal getaway to savor during summer.',
#   0.5604647994041443),
#  ('Santorini offers stunning views to admire during spring.',
#   0.5512217283248901),
#  ('Banff National Park is a picturesque destination to visit in the summer.',
#   0.5220370888710022),
#  ("Kyoto's cherry blossoms create a beautiful scene to witness during spring.",
#   0.5150064826011658),
#  ('The fjords of Norway are a magical place to cruise through in the spring.',
#   0.48470333218574524),
#  ('The Christmas markets in Vienna are a festive delight to explore in winter.',
#   0.4710915684700012),
#  ('Marrakech offers vibrant markets and culture to enjoy in the fall.',
#   0.4674418270587921),
#  ('Prague is an enchanting city to wander through in winter.',
#   0.44837242364883423)]

# %%
score = retrieve_relevant(query, documents, metric='euclidean_distance')
score
# Out:
# [('The Great Wall of China is a spectacular site to experience during winter.',
#   0.8853791952133179),
#  ('Mt. Fuji is a breathtaking place to explore during autumn.',
#   0.9141674041748047),
#  ('The Maldives are a paradisiacal getaway to savor during summer.',
#   0.9375876188278198),
#  ('Santorini offers stunning views to admire during spring.',
#   0.9473946690559387),
#  ('Banff National Park is a picturesque destination to visit in the summer.',
#   0.9777146577835083),
#  ("Kyoto's cherry blossoms create a beautiful scene to witness during spring.",
#   0.9848793745040894),
#  ('The fjords of Norway are a magical place to cruise through in the spring.',
#   1.0151814222335815),
#  ('The Christmas markets in Vienna are a festive delight to explore in winter.',
#   1.0285024642944336),
#  ('Marrakech offers vibrant markets and culture to enjoy in the fall.',
#   1.032044768333435),
#  ('Prague is an enchanting city to wander through in winter.',
#   1.0503594875335693)]
